# %%
# %reload_ext autoreload
# %autoreload 2

import os
import argparse
import sys
import time
import cv2

from joblib import Parallel, delayed

sys.path.append(os.path.join(os.environ['GORDON_REPO_DIR'], 'utilities'))
from utilities2015 import *

from matplotlib.path import Path
# %matplotlib inline

import scipy.ndimage as nd
import scipy

from skimage.feature import hog
from skimage import data, color, exposure

# %%
# Load and show a sample of image
img = imread('/oasis/projects/nsf/csd395/yuncong/CSHL_data_processed/MD589_lossless_aligned_cropped_grayscale/MD589_0134_lossless_aligned_cropped_grayscale.tif')
im = img[8000:8000+208, 8100:8100+208] # im is a ndimage

# %%
plt.figure(figsize=(10,10));
plt.imshow(im, cmap=plt.cm.gray);
plt.axis('off');
plt.title('sample image');

# %%
fd, hog_image = hog(im, orientations=8, pixels_per_cell=(4, 4),
                    cells_per_block=(1, 1), normalise=True, visualise=True);

# %%
plt.figure(figsize=(10,10));
plt.imshow(hog_image, cmap=plt.cm.gray);
plt.axis('off');
plt.title('HoG image');

# %%
sift = cv2.SIFT();
key_point = sift.detect(im, None);
kp_image=cv2.drawKeypoints(im, key_point);

# %%
plt.figure(figsize=(10,10));
plt.imshow(kp_image, cmap=plt.cm.gray);
plt.axis('off');
plt.title('SIFT Key Point image')
