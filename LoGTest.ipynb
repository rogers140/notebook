# %%
# %reload_ext autoreload
# %autoreload 2

import os
import argparse
import sys
import time
from joblib import Parallel, delayed

from matplotlib.path import Path
# %matplotlib inline

import scipy.ndimage as nd
import scipy
import matplotlib.pyplot as plt

# %%
img = scipy.misc.imread('/oasis/projects/nsf/csd395/yuncong/CSHL_data_processed/MD589_lossless_aligned_cropped_grayscale/MD589_0134_lossless_aligned_cropped_grayscale.tif')
im = img[7245:7245+208, 2845:2845+190]
# Out:
# /oasis/projects/nsf/csd181/yuncong/virtualenv-1.9.1/yuncongve/lib/python2.7/site-packages/PIL/Image.py:2261: DecompressionBombWarning: Image size (294524928 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning)

# %%
plt.figure(figsize=(10,10));
plt.imshow(im, cmap=plt.cm.gray);
plt.axis('off');
plt.title('image');
